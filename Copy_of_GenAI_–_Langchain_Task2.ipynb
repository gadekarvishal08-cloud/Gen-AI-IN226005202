# %%
# !pip install -q langchain langchain-openai langchain-core langchain-community python-dotenv

# %%
import os

os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

print("LLM Loaded Successfully")

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

print(template.format(topic="Artificial Intelligence"))

# %%
response = llm.invoke("Explain Machine Learning in simple terms")
print(response.content)

# %%
from langchain.memory import ConversationBufferMemory

memory = ConversationBufferMemory()

memory.save_context({"input": "Hello"}, {"output": "Hi"})
print(memory.load_memory_variables({}))

# %%
# !pip install -q langchain langchain-openai

import os
os.environ["OPENAI_API_KEY"] = "your_api_key"

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

response = llm.invoke("Explain AI in simple terms")
print(response.content)

# %%
chain = template | llm
print(chain.invoke({"topic": "Deep Learning"}).content)
